# %% [markdown]
# # Import Dataset

# %%
import tensorflow as tf
from sklearn.datasets import fetch_olivetti_faces
from sklearn.preprocessing import LabelBinarizer

data = fetch_olivetti_faces(shuffle = True)
labels = LabelBinarizer().fit_transform(data.target)

# Training Data
images_DataTraining = data.data[0:299]
labels_DataTraining = labels[0:299]

# Validation Data
images_DataValidation = data.data[299:349]
labels_DataValidation = labels[299:349]

# Testing Data
images_DataTesting = data.data[349:399]
labels_DataTesting = labels[349:399]

# %% [markdown]
# # Convolution and Pooling Layers

# %% [markdown]
# Input Layer -> 1st Convolutional Layer -> 1st Pooling Layer -> 2nd Convolutional Layer -> 2nd Pooling Layer -> 3rd Convolutional Layer -> 3rd Pooling Layer -> Fully Connected Layer -> Output Layer

# %%
x = tf.placeholder(tf.float32, [None, 4096])
y_ = tf.placeholder(tf.float32, [None, 40])

# Add function to create weight variable 
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev = 0.1)
    return tf.Variable(initial)

# Add function to create bias variable 
def bias_variable(shape):
    initial = tf.constant(0.1, shape = shape)
    return tf.Variable(initial)

# Add convolution function
def conv2d(x, W):
    return(tf.nn.conv2d(x, W, strides = [1, 1, 1, 1], padding = "SAME"))

# Add Pooling function
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = "SAME")

# Reshape the data for inputting it in the input layer
x_image = tf.reshape(x, [-1, 64, 64, 1])

# Create 1st Convolutional and Pooling Layer
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)


# Create 2nd Convolutional and Pooling Layer
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)


# Create 3rd Convolutional and Pooling Layer
W_conv3 = weight_variable([5, 5, 64, 128])
b_conv3 = bias_variable([128])

h_conv3 = tf.nn.relu(conv2d(h_pool2, W_conv3) + b_conv3)
h_pool3 = max_pool_2x2(h_conv3)

# 1st Fully Connected Layer
W_fc1 = weight_variable([128*8*8, 1024])
b_fc1 = bias_variable([1024])

# Reshape the last convolutional layer output to connect with Fully Connected Layer
h_pool2_flat = tf.reshape(h_pool3, [-1, 128*8*8])

h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

# Add the dropout layer
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# Output Layer
W_fc2 = weight_variable([1024, 40])
b_fc2 = bias_variable([40])

y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# %% [markdown]
# # Training

# %%
# Network base of Computation
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = y_, logits = y_conv))
training_op  = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)

# Prediction Measures
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# Mention about the number of epochs training has to happen
#epochs = 1100

saver = tf.train. Saver()

n_epochs = 200

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(n_epochs):
        sess.run(training_op, feed_dict = {x : images_DataTraining, y_:labels_DataTraining, keep_prob : 0.5})
        acc_train = accuracy.eval(feed_dict={x : images_DataTraining, y_:labels_DataTraining, keep_prob : 1.0})
        acc_validation = accuracy.eval(feed_dict={x : images_DataValidation, y_:labels_DataValidation, keep_prob : 1.0})
        print(epoch, "Train accuracy", acc_train, "Validation accuracy", acc_validation)
    save_path = saver.save(sess, "./my_model_find.ckpt")
# Out:
# 0 Train accuracy 0.016722407 Validation accuracy 0.0
# 1 Train accuracy 0.02341137 Validation accuracy 0.04
# 2 Train accuracy 0.02341137 Validation accuracy 0.02
# 3 Train accuracy 0.030100334 Validation accuracy 0.0
# 4 Train accuracy 0.030100334 Validation accuracy 0.0
# 5 Train accuracy 0.036789298 Validation accuracy 0.0
# 6 Train accuracy 0.04682274 Validation accuracy 0.0
# 7 Train accuracy 0.06688963 Validation accuracy 0.02
# 8 Train accuracy 0.07023411 Validation accuracy 0.04
# 9 Train accuracy 0.06354515 Validation accuracy 0.04
# 10 Train accuracy 0.06354515 Validation accuracy 0.04
# 11 Train accuracy 0.073578596 Validation accuracy 0.02
# 12 Train accuracy 0.08695652 Validation accuracy 0.0
# 13 Train accuracy 0.09364548 Validation accuracy 0.02
# 14 Train accuracy 0.12040134 Validation accuracy 0.02
# 15 Train accuracy 0.13043478 Validation accuracy 0.02
# 16 Train accuracy 0.14046822 Validation accuracy 0.02
# 17 Train accuracy 0.12040134 Validation accuracy 0.02
# 18 Train accuracy 0.117056854 Validation accuracy 0.02
# 19 Train accuracy 0.110367894 Validation accuracy 0.02
# 20 Train accuracy 0.117056854 Validation accuracy 0.02
# 21 Train accuracy 0.14046822 Validation accuracy 0.02
# 22 Train accuracy 0.17391305 Validation accuracy 0.02
# 23 Train accuracy 0.20401338 Validation accuracy 0.04
# 24 Train accuracy 0.2374582 Validation accuracy 0.04
# 25 Train accuracy 0.2575251 Validation accuracy 0.1
# 26 Train accuracy 0.26755852 Validation accuracy 0.16
# 27 Train accuracy 0.29765886 Validation accuracy 0.16
# 28 Train accuracy 0.31772575 Validation accuracy 0.16
# 29 Train accuracy 0.3645485 Validation accuracy 0.16
# 30 Train accuracy 0.40468228 Validation accuracy 0.12
# 31 Train accuracy 0.4214047 Validation accuracy 0.12
# 32 Train accuracy 0.46822742 Validation accuracy 0.08
# 33 Train accuracy 0.48160535 Validation accuracy 0.12
# 34 Train accuracy 0.4949833 Validation accuracy 0.14
# 35 Train accuracy 0.5217391 Validation accuracy 0.14
# 36 Train accuracy 0.53511703 Validation accuracy 0.16
# 37 Train accuracy 0.5518395 Validation accuracy 0.22
# 38 Train accuracy 0.56856185 Validation accuracy 0.24
# 39 Train accuracy 0.6187291 Validation accuracy 0.26
# 40 Train accuracy 0.632107 Validation accuracy 0.3
# 41 Train accuracy 0.6588629 Validation accuracy 0.34
# 42 Train accuracy 0.67892975 Validation accuracy 0.3
# 43 Train accuracy 0.70234114 Validation accuracy 0.28
# 44 Train accuracy 0.70234114 Validation accuracy 0.3
# 45 Train accuracy 0.7056856 Validation accuracy 0.32
# 46 Train accuracy 0.71571904 Validation accuracy 0.34
# 47 Train accuracy 0.72575253 Validation accuracy 0.38
# 48 Train accuracy 0.7424749 Validation accuracy 0.38
# 49 Train accuracy 0.75250834 Validation accuracy 0.42
# 50 Train accuracy 0.76254183 Validation accuracy 0.46
# 51 Train accuracy 0.78929764 Validation accuracy 0.48
# 52 Train accuracy 0.7993311 Validation accuracy 0.5
# 53 Train accuracy 0.8060201 Validation accuracy 0.48
# 54 Train accuracy 0.81270903 Validation accuracy 0.46
# 55 Train accuracy 0.8327759 Validation accuracy 0.46
# 56 Train accuracy 0.8394649 Validation accuracy 0.46
# 57 Train accuracy 0.8428094 Validation accuracy 0.5
# 58 Train accuracy 0.8528428 Validation accuracy 0.5
# 59 Train accuracy 0.84949833 Validation accuracy 0.5
# 60 Train accuracy 0.8695652 Validation accuracy 0.5
# 61 Train accuracy 0.8862876 Validation accuracy 0.52
# 62 Train accuracy 0.89632106 Validation accuracy 0.54
# 63 Train accuracy 0.89632106 Validation accuracy 0.5
# 64 Train accuracy 0.909699 Validation accuracy 0.5
# 65 Train accuracy 0.91973245 Validation accuracy 0.54
# 66 Train accuracy 0.916388 Validation accuracy 0.58
# 67 Train accuracy 0.9297659 Validation accuracy 0.58
# 68 Train accuracy 0.93645483 Validation accuracy 0.58
# 69 Train accuracy 0.9397993 Validation accuracy 0.62
# 70 Train accuracy 0.9464883 Validation accuracy 0.62
# 71 Train accuracy 0.9498328 Validation accuracy 0.62
# 72 Train accuracy 0.9498328 Validation accuracy 0.62
# 73 Train accuracy 0.95652175 Validation accuracy 0.62
# 74 Train accuracy 0.9665552 Validation accuracy 0.62
# 75 Train accuracy 0.9632107 Validation accuracy 0.62
# 76 Train accuracy 0.96989965 Validation accuracy 0.6
# 77 Train accuracy 0.96989965 Validation accuracy 0.6
# 78 Train accuracy 0.96989965 Validation accuracy 0.6
# 79 Train accuracy 0.97324413 Validation accuracy 0.62
# 80 Train accuracy 0.9765886 Validation accuracy 0.66
# 81 Train accuracy 0.9799331 Validation accuracy 0.66
# 82 Train accuracy 0.9799331 Validation accuracy 0.66
# 83 Train accuracy 0.9799331 Validation accuracy 0.68
# 84 Train accuracy 0.9799331 Validation accuracy 0.68
# 85 Train accuracy 0.9799331 Validation accuracy 0.7
# 86 Train accuracy 0.9799331 Validation accuracy 0.68
# 87 Train accuracy 0.9832776 Validation accuracy 0.7
# 88 Train accuracy 0.9799331 Validation accuracy 0.7
# 89 Train accuracy 0.9799331 Validation accuracy 0.74
# 90 Train accuracy 0.9866221 Validation accuracy 0.76
# 91 Train accuracy 0.9866221 Validation accuracy 0.76
# 92 Train accuracy 0.9899666 Validation accuracy 0.74
# 93 Train accuracy 0.9899666 Validation accuracy 0.74
# 94 Train accuracy 0.99331105 Validation accuracy 0.74
# 95 Train accuracy 0.99331105 Validation accuracy 0.74
# 96 Train accuracy 0.9966555 Validation accuracy 0.74
# 97 Train accuracy 0.9966555 Validation accuracy 0.76
# 98 Train accuracy 0.9966555 Validation accuracy 0.76
# 99 Train accuracy 0.9966555 Validation accuracy 0.76
# 100 Train accuracy 0.9966555 Validation accuracy 0.76
# 101 Train accuracy 0.99331105 Validation accuracy 0.76
# 102 Train accuracy 0.99331105 Validation accuracy 0.76
# 103 Train accuracy 0.99331105 Validation accuracy 0.76
# 104 Train accuracy 0.9966555 Validation accuracy 0.76
# 105 Train accuracy 1.0 Validation accuracy 0.76
# 106 Train accuracy 1.0 Validation accuracy 0.76
# 107 Train accuracy 1.0 Validation accuracy 0.82
# 108 Train accuracy 0.9966555 Validation accuracy 0.82
# 109 Train accuracy 0.9966555 Validation accuracy 0.82
# 110 Train accuracy 0.9966555 Validation accuracy 0.82
# 111 Train accuracy 0.9966555 Validation accuracy 0.82
# 112 Train accuracy 0.9966555 Validation accuracy 0.82
# 113 Train accuracy 0.9966555 Validation accuracy 0.76
# 114 Train accuracy 0.9966555 Validation accuracy 0.76
# 115 Train accuracy 0.9966555 Validation accuracy 0.76
# 116 Train accuracy 0.9966555 Validation accuracy 0.78
# 117 Train accuracy 0.9966555 Validation accuracy 0.78
# 118 Train accuracy 0.9966555 Validation accuracy 0.78
# 119 Train accuracy 0.9966555 Validation accuracy 0.8
# 120 Train accuracy 0.9966555 Validation accuracy 0.82
# 121 Train accuracy 0.9966555 Validation accuracy 0.84
# 122 Train accuracy 0.9966555 Validation accuracy 0.82
# 123 Train accuracy 0.9966555 Validation accuracy 0.82
# 124 Train accuracy 0.9966555 Validation accuracy 0.82
# 125 Train accuracy 1.0 Validation accuracy 0.8
# 126 Train accuracy 1.0 Validation accuracy 0.78
# 127 Train accuracy 1.0 Validation accuracy 0.78
# 128 Train accuracy 1.0 Validation accuracy 0.78
# 129 Train accuracy 1.0 Validation accuracy 0.8
# 130 Train accuracy 1.0 Validation accuracy 0.8
# 131 Train accuracy 1.0 Validation accuracy 0.82
# 132 Train accuracy 1.0 Validation accuracy 0.84
# 133 Train accuracy 1.0 Validation accuracy 0.84
# 134 Train accuracy 1.0 Validation accuracy 0.84
# 135 Train accuracy 1.0 Validation accuracy 0.84
# 136 Train accuracy 1.0 Validation accuracy 0.82
# 137 Train accuracy 1.0 Validation accuracy 0.82
# 138 Train accuracy 1.0 Validation accuracy 0.82
# 139 Train accuracy 1.0 Validation accuracy 0.82
# 140 Train accuracy 1.0 Validation accuracy 0.84
# 141 Train accuracy 1.0 Validation accuracy 0.84
# 142 Train accuracy 1.0 Validation accuracy 0.84
# 143 Train accuracy 1.0 Validation accuracy 0.82
# 144 Train accuracy 1.0 Validation accuracy 0.82
# 145 Train accuracy 1.0 Validation accuracy 0.82
# 146 Train accuracy 1.0 Validation accuracy 0.82
# 147 Train accuracy 1.0 Validation accuracy 0.82
# 148 Train accuracy 1.0 Validation accuracy 0.82
# 149 Train accuracy 1.0 Validation accuracy 0.8
# 150 Train accuracy 1.0 Validation accuracy 0.82
# 151 Train accuracy 1.0 Validation accuracy 0.84
# 152 Train accuracy 1.0 Validation accuracy 0.84
# 153 Train accuracy 1.0 Validation accuracy 0.84
# 154 Train accuracy 1.0 Validation accuracy 0.86
# 155 Train accuracy 1.0 Validation accuracy 0.86
# 156 Train accuracy 1.0 Validation accuracy 0.86
# 157 Train accuracy 1.0 Validation accuracy 0.86
# 158 Train accuracy 1.0 Validation accuracy 0.86
# 159 Train accuracy 1.0 Validation accuracy 0.86
# 160 Train accuracy 1.0 Validation accuracy 0.86
# 161 Train accuracy 1.0 Validation accuracy 0.86
# 162 Train accuracy 1.0 Validation accuracy 0.86
# 163 Train accuracy 1.0 Validation accuracy 0.86
# 164 Train accuracy 1.0 Validation accuracy 0.86
# 165 Train accuracy 1.0 Validation accuracy 0.86
# 166 Train accuracy 1.0 Validation accuracy 0.86
# 167 Train accuracy 1.0 Validation accuracy 0.86
# 168 Train accuracy 1.0 Validation accuracy 0.84
# 169 Train accuracy 1.0 Validation accuracy 0.88
# 170 Train accuracy 1.0 Validation accuracy 0.88
# 171 Train accuracy 1.0 Validation accuracy 0.88
# 172 Train accuracy 1.0 Validation accuracy 0.86
# 173 Train accuracy 1.0 Validation accuracy 0.84
# 174 Train accuracy 1.0 Validation accuracy 0.84
# 175 Train accuracy 1.0 Validation accuracy 0.86
# 176 Train accuracy 1.0 Validation accuracy 0.86
# 177 Train accuracy 1.0 Validation accuracy 0.86
# 178 Train accuracy 1.0 Validation accuracy 0.9
# 179 Train accuracy 1.0 Validation accuracy 0.9
# 180 Train accuracy 1.0 Validation accuracy 0.9
# 181 Train accuracy 1.0 Validation accuracy 0.88
# 182 Train accuracy 1.0 Validation accuracy 0.88
# 183 Train accuracy 1.0 Validation accuracy 0.88
# 184 Train accuracy 1.0 Validation accuracy 0.88
# 185 Train accuracy 1.0 Validation accuracy 0.88
# 186 Train accuracy 1.0 Validation accuracy 0.88
# 187 Train accuracy 1.0 Validation accuracy 0.88
# 188 Train accuracy 1.0 Validation accuracy 0.88
# 189 Train accuracy 1.0 Validation accuracy 0.88
# 190 Train accuracy 1.0 Validation accuracy 0.9
# 191 Train accuracy 1.0 Validation accuracy 0.88
# 192 Train accuracy 1.0 Validation accuracy 0.88
# 193 Train accuracy 1.0 Validation accuracy 0.88
# 194 Train accuracy 1.0 Validation accuracy 0.88
# 195 Train accuracy 1.0 Validation accuracy 0.9
# 196 Train accuracy 1.0 Validation accuracy 0.9
# 197 Train accuracy 1.0 Validation accuracy 0.9
# 198 Train accuracy 1.0 Validation accuracy 0.9
# 199 Train accuracy 1.0 Validation accuracy 0.9

# %%
with tf.Session() as sess:
    saver.restore(sess, "./my_model_find.ckpt")
    acc_testing = accuracy.eval(feed_dict={x : images_DataTesting, y_:labels_DataTesting, keep_prob : 1})
    print("Testing accuracy", acc_testing)
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_find.ckpt
# Testing accuracy 0.96
